# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohitlodhii/machine_learning/blob/main/inear_regression/polynomialRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt


from sklearn.linear_model import LinearRegression , SGDRegressor
from sklearn.preprocessing import PolynomialFeatures , StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline

# %% [markdown]
# EQN =
#
# Y = 0.8^2 + 0.9^X + 2 + NOISE

# %%
X = 6 * np.random.rand(200 , 1 ) - 3
Y = 0.8 * X**2 + 0.9 * X + 2 + np.random.randn(200 ,1 )

# %%
plt.scatter(X, Y, color='blue', alpha=0.5)
plt.title("Synthetic Polynomial Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
#Train Test Split

X_train , X_test ,Y_train ,Y_test = train_test_split(X,Y,test_size=0.2,random_state=3)

# %%
# creating a instance of the class LInearRegression\

lr= LinearRegression()
lr.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
r2_score(Y_test , y_pred)
# Out:
# 0.30257918296053554

# %%
poly = PolynomialFeatures(degree=2 , include_bias=True)

X_train_trans = poly.fit_transform(X_train)
X_test_trans = poly.transform(X_test)

print(X_train[0])
print(X_train_trans[0])
# Out:
# [1.85897511]
# [1.         1.85897511 3.45578846]

# %%
lr = LinearRegression()

lr.fit(X_train_trans , Y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test_trans)
r2_score(Y_test , y_pred)
# Out:
# 0.8640853954419577

# %%
#3D Polynomial Regression

x = 7 * np.random.rand(100 , 1) - 2.8
y = 7 * np.random.rand(100 ,1) - 2.8

z = x**2 + y**2 + 0.2*x + 0.2*y + 0.1*x*y + 2 + np.random.randn(100,1)

# %%
import plotly.express as px


df = px.data.iris()
fir = px.scatter_3d(df , x=x.ravel() , y=y.ravel() , z=z.ravel())
fir.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
